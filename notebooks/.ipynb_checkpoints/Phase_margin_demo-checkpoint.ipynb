# %% [markdown]
# #Phase margin demo
# <br>
# This notebook is designed to make the students learn about the phase margin of a proportional controller.
# <br>
# <br>It will show how to calculate the phase margin with a Bode plot and Nyquist diagram.
# <br>
#
#
# <img src='feedback_pitch2.png'>

# %%
from phase_margin import *
###This are the imported packages, control is not a standard package of Anaconda.

# %% [markdown]
# The phase margin is the difference between the angle at the the frequency, at which the magnitude is equal to $0$ dB(= when $|P(jw_0)C(jw_0)|=1$), and $-180°$. For $H(s)= \frac{1}{s^2+s}$ is this for example $52°$
# <br>
# You can see this on the Bode plot and on the Nyquist plot:
# <br>
#  - On the Bode plot you just look at what frequency the magnitude plot is $0$ and see what the difference is between the angle at that frequency and $-180°$.
#  - At the Nyquist plot you calculate the argument that the Nyquist diagram makes with the unity circle.

# %%
# %matplotlib inline
num = [1]
den = [1,1,0]
TF = control.TransferFunction(num,den)
Showbode = input_handler_y_n("Do you want to check this for yourself?(Y/N) ")
###Showbode is a Boolean that says wheater you wan't to show the example or not.        
if Showbode==True:
    control.bode(TF,dB=True)
    draw_lines_bode(TF)
    plt.show ()
    control.nyquist_plot(TF,Plot=True, color='b', labelFreq=0)
    draw_lines_nyquist(TF)
    plt.show ()
###These are commands to plot the Bode plot and the Nyquist plot and ad extra's such as axises and lines to                                                                                     
###show the phase margin.
# Out:
# Do you want to check this for yourself?(Y/N) y

# %% [markdown]
# Let's try now to calculate the phase margin of a chosen transfer function. A hint, not all transfer functions have a phase margin, look carefull at the Bode plot first! Give in the coëfficiënts of the transfer function.

# %%
###These while-loops make sure that the user gives in the usefull input.


YN = False
###After plotting the transfer function, the user can see if it makes sense to continue 
###with the transfer function.
###The next loops are written if the user want's to change his/her transfer function and always plots
###the bode plot of the transfer function.
while YN == False:
    Nom = input_handler_lst("Enter the numerator of the transfer function(a_n*s^n+...+a_1*s+a_0 = a_n, ..., a_1, a_0 )= ")
    DeNom = input_handler_lst("Give in the denominator of the transfer function(a_n*s^n+...+a_1*s+a_0 = a_n, ..., a_1, a_0 )= ")
    TF_in = control.TransferFunction(Nom,DeNom)
    print TF_in
    control.bode(TF_in,dB=True)
    draw_lines_bode(TF_in)
    plt.show ()
    print "Not all transfer functions are necessarily good transfer functions For example, if your phase plot of your Bode diagram doesn't come near the region of -180°, it makes no sense to set a criteria like: I want to have 30 degrees  phase margin."
    print "So, do you want to continue with your given transfer function?"
    YN = input_handler_y_n("(Y/N)")
    
### The next command show the phasemargin to the user        
GM,PM,X1,X2 = control.margin(TF_in)
if PM == None:
    print "                                                                                        "
    print "The phase margin is either very high, or it doesn't make sense to define the phase margin."
else:
    print "                    "
    print "The phase margin is, ",PM,"°"
# Out:
# Enter the numerator of the transfer function(a_n*s^n+...+a_1*s+a_0 = a_n, ..., a_1, a_0 )= 1
# Give in the denominator of the transfer function(a_n*s^n+...+a_1*s+a_0 = a_n, ..., a_1, a_0 )= 1,1,0
#
#    1
# -------
# s^2 + s
# Not all transfer functions are necessarily good transfer functions For example, if your phase plot of your Bode diagram doesn't come near the region of -180°, it makes no sense to set a criteria like: I want to have 30 degrees  phase margin.
# So, do you want to continue with your given transfer function?
# (Y/N)y
#
# The phase margin is,  51.827292373 °

# %% [markdown]
# We calculated the phase margin at the beginning, when there was no controller yet. A proportional controller $C(s)$ has a certain constant value $K$, that has an influence on the magnitude plot.(But not on the phase plot!)
# <br>
# When you design a controller, a design objective for the controller can be:
# "Design the controller in order that there is at least 30° degrees  phase margin."
# <br>
# If we look at $H(s)= \frac{1}{(s^2+s)}$ again and let's say you want at least $30°$ phase margin, the maximum value for $K$ is $3.46$. How do we find this $K$?
# <br>
# First, find on the phase plot the frequency at which the phase plot equals $-150°$. Then, see what the amplitude at that frequency is. With that amplitude,$ K$ can easily be calculated. Since the $amplitude = 20*log_{10}(K)$, $K = 10^{\frac{amplitude}{20}}$.
#
# <br> This gives $K=3.46$
# <br> Do you want to calculate this yourself?

# %%
###Some objective as the previous loops
Showbode = input_handler_y_n("(Y/N)")
if Showbode==True:
    num = [1]
    den = [1,1,0]
    TF_vb = control.TransferFunction([1],[1,1,0])
    gm,pm,x1,x2 = control.margin(TF_vb)   
    control.bode(TF,dB=True)
    draw_lines_bode(TF_vb)
    plt.show ()
    control.nyquist_plot(TF,Plot=True, color='b', labelFreq=0)
    draw_lines_nyquist(TF_vb)
    plt.show ()
###Shows Bode plot and Nyquist of the transfer function given in by the user, with extra axises and lines
###to make it easier to see how you calculate the phasemargin.
print "Now, let's do this calculation for your transferfunction." 
gm,pm,x1,x2 = control.margin(TF_in)   
control.bode(TF_in,dB=True)
draw_lines_bode(TF_in)
plt.show ()
control.nyquist_plot(TF_in,Plot=True, color='b', labelFreq=0)
draw_lines_nyquist(TF_in)
plt.show ()
print 
print "If your given transfer function had a phasemargin that made sense (and higher then 30°), K should be:"
if PM == None:
    PM = 10000
PMS = 30
teller = 0
K = 1
### Algorithm for calculating the K from the controller.
while abs(PM-PMS)>0.1 and PM>PMS and teller<50:
    if PM > 60+PMS:
        K = K*3
        teller+=1
    elif PM > 45+PMS:
        K = K*2
        teller+=1
    elif PM > 20+PMS:
        K= K+2
    elif PM > 10+PMS:
        K= K+1
    elif PM > 5+PMS:
        K = K+0.5                      
    GM,PM,X1,X2= control.margin(K*TF_in)
    if PM == None:
        PM =10000
    K = K+0.001
###Output for the user about the K of his/her  controller    
if teller != 50:
    print "                                        "
    print K
    
if teller == 50:
    print "                                   "
    print "Transferfunction doesn't make sense"
print "                                   "
print "For more exercices, see the demo Simplecontrollerdemo"
# Out:
# (Y/N)y
# Now, let's do this calculation for your transferfunction.
# If your given transfer function had a phasemargin that made sense (and higher then 30°), K should be:
#
# 3.441
#
# For more exercices, see the demo Simplecontrollerdemo
