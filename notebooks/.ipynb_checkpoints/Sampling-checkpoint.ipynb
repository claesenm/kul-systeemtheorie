# %% [markdown]
# # Sampling

# %% [markdown]
# ## Signal

# %%
from sampling import *

# %matplotlib inline

def selector():
    print select_input.value
    for i in options.values():
        sliders[i].visible = (i==select_input.value)
            
    

select_input.on_trait_change(selector)

#N = 500
#T = 1/700.0
#t = np.linspace(-N*T/2.0,N*T/2.0,N)
#y = np.sin(2*np.pi*100*t)/t
## t,y = input_selector()
#plt.plot(t,y)
#plt.show()

# %%
from sampling import *
# %matplotlib inline
display(box)

# %% [markdown]
# ## Fourier Transform

# %%
from sampling import y_signal,t_signal
yf = 2.0/N * np.abs(fourier.fft(y_signal))
xf = np.fft.fftfreq(len(y_signal), t_signal[1] - t_signal[0])
plt.plot(xf,yf)
plt.show()

# %% [markdown]
# ## Sampling speed

# %%
N_dirac = 10000
T_dirac = 1/1000.0
tdf = None
diracf = None
def sampling_dirac(f):
    global tdf,diracf
    Period = 1/f
    down = Period*(1/T_dirac) -1
    temp = [0]*int(down) + [1]
    y_dirac = temp*int((N_dirac/(down+1)))
    t_dirac = np.linspace(-N_dirac*T_dirac/2,N_dirac*T_dirac/2,len(y_dirac))
    print len(t_dirac),len(y_dirac)
    plt.plot(t_dirac,y_dirac)
    plt.xlim(-20*Period,20*Period)
    plt.show()
    diracf = 2.0/N * np.abs(fourier.fft(y_dirac))
    tdf = np.fft.fftfreq(len(diracf), t_dirac[1] - t_dirac[0])
    plt.plot(tdf, diracf)
    plt.show() 
sampling_dirac(100.0)
# Out:
# 9000 9000

# %% [markdown]
# #Sampling

# %%
samplef = np.convolve(fourier.fftshift(yf),fourier.fftshift(diracf),'same')
N_sample = len(samplef)
ct = np.linspace(-N_dirac*T_dirac/2,N_dirac*T_dirac/2,N_sample)
plt.plot(ct,samplef)
plt.show()

# %% [markdown]
# ## Discrete time

# %%
dt = result[0:500] * y
print len(dt)
plt.plot(t,dt)
plt.xlim(-0.1,0.1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-8fc37cca3e5f> in <module>()
# ----> 1 dt = result[0:500] * y
#       2 print len(dt)
#       3 plt.plot(t,dt)
#       4 plt.xlim(-0.1,0.1)
#       5 plt.show()
#
# NameError: name 'result' is not defined

# %% [markdown]
# ## Reconstruction

# %%
res = np.convolve(yf,resultf,'same')
